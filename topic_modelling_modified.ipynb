# %% [markdown]
# # Topic modelling using BERTopic

# %% [markdown]
# ## Libraries/data required

# %%
# IMPORTS
from bertopic import BERTopic
import pandas as pd
import os

# helper functions
from helper_functions import get_relevant_topics
# Out:
# /home/egor/.local/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/egor/.local/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/egor/.local/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/egor/.local/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# 2023-10-12 16:08:36.590725: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-12 16:08:36.590761: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-12 16:08:36.590794: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-12 16:08:36.599265: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-12 16:08:37.692477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Read the data and perform preprocessing

df = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"]) # Read data into 'df' dataframe
print(df.shape) # Print dataframe shape

docs = df["summary"].tolist() # Create a list containing all article summaries

df.head() # Show first 5 dataframe entries
# Out:
# (18520, 5)
#                                              summary       date  \
# 0  The article discusses the passing of the new C... 2011-07-07
# 1  The article discusses the military actions tak... 2011-07-03
# 2  The article discusses the signing of a Framewo... 2011-06-30
# 3  The article discusses the upcoming independenc... 2011-07-04
# 4  The article discusses the need for South Sudan... 2011-07-02
#
#     location_article        lat        lng
# 0               Juba   4.859363  31.571250
# 1              Abyei   9.838551  28.486396
# 2  Southern Kordofan  11.036544  30.895824
# 3        South Sudan   6.876992  31.306979
# 4               Juba   4.859363  31.571250

# %% [markdown]
# ## Fitting BERTopic
#
# This might take a while on a CPU. In the background a pre-trained Large Language Model, called the sentence embedder, is used to convert the articles to a semantic vector space. We then perform clustering in this space.

# %%
if os.path.exists('southsudan_model'):
    bertopic = BERTopic.load('southsudan_model')
else:
    bertopic = BERTopic(language="english", calculate_probabilities=True, verbose=True) # Initialize the BERTopic model

    bertopic.fit_transform(docs) # Fit the model to the list of article summaries
    print("dupa")
    bertopic.save("southsudan_model") # Save the trained model as "southsudan_model"

# %% [markdown]
# ## Interactive visualization of the vector space
#
# As you can see, documents with related topics are close in the space.

# %%
# bertopic.visualize_documents(docs) # Create a plot of the topics, this may take a while

# %% [markdown]
# ### Creating smaller topics
#
# Within our list of topics, we find topics that are semantically closest to 4 keywords:
#
# "Hunger", "Refugees", "Conflict", and "Humanitarian".
#
# **Feel free to change this approach!**

# %%
# Get the top 10 topics related to the keywords 'hunger' and 'food insecurity'
relevant_topics = get_relevant_topics(bertopic_model = bertopic, keywords=['hunger',
                                                                           'food insecurity',
                                                                           'famine',
                                                                           'malnutrition'], top_n=10)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)
    
df["hunger"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 121 0.5489128
# 7 0.51720685
# 171 0.4492692
# 63 0.4309224
# 25 0.3723547
# 14 0.36774674
# 172 0.35742354
# 97 0.33924705
# 31 0.33701497
# 45 0.32990852
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/egor/Desktop/Study Materials/DC3-Group-13/topic_modelling_modified.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling_modified.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a> for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling_modified.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>     print(topic_id, relevancy)
# ---> <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling_modified.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> df["hunger"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling_modified.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> # View the Count, Name, Representation, and Representative Docs for the relevant topics
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling_modified.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4538, in DataFrame._sanitize_column(self, value)
#    4535     return _reindex_for_setitem(value, self.index)
#    4537 if is_list_like(value):
# -> 4538     com.require_length_match(value, self.index)
#    4539 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (18226) does not match length of index (18520)

# %%
bertopic.get_topic_info()["Name"][3]
# Out:
# '2_education_students_university_school'

# %%
# Get the top 10 topics related to the keywords 'refugees' and 'displaced'
relevant_topics = get_relevant_topics(bertopic_model = bertopic, keywords=['refugees', 'displaced'], top_n=10)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)
    
df["refugees"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 33 0.63444126
# 143 0.6034603
# 182 0.5878446
# 204 0.5816232
# 39 0.5686121
# 189 0.5625057
# 55 0.5625042
# 95 0.5536663
# 184 0.5500035
# 96 0.531736
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/egor/Desktop/Study Materials/DC3-Group-13/topic_modelling.ipynb Cell 12 line 9
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     print(topic_id, relevancy)
# ----> <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> df["refugees"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> # View the Count, Name, Representation, and Representative Docs for the relevant topics
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4538, in DataFrame._sanitize_column(self, value)
#    4535     return _reindex_for_setitem(value, self.index)
#    4537 if is_list_like(value):
# -> 4538     com.require_length_match(value, self.index)
#    4539 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (18226) does not match length of index (18520)

# %%
# Get the top 10 topics related to the keyword 'humanitarian'
relevant_topics = get_relevant_topics(bertopic_model = bertopic, keywords=['humanitarian'], top_n=10)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)
    
df["humanitarian"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 31 0.6197233
# 222 0.61494356
# 84 0.59816206
# 201 0.5787014
# 220 0.55819273
# 161 0.54312235
# 198 0.5380315
# 12 0.53338945
# 209 0.52747047
# 88 0.5249189
#        Count                                         Name  \
# Topic
# 31        89       31_humanitarian_million_aid_assistance
# 222       10         222_humanitarian_eu_million_european
# 84        38           84_workers_aid_humanitarian_killed
# 201       13  201_humanitarian_returns_displaced_violence
# 220       10                  220_red_cross_ifrc_crescent
# 161       19            161_oxfam_oxfams_aid_humanitarian
# 198       13                   198_maban_aid_workers_bunj
# 12       149               12_unmiss_un_civilians_mission
# 209       12                    209_ngos_aid_workers_bill
# 88        37               88_darfur_unamid_dabanga_radio
#
#                                           Representation  \
# Topic
# 31     [humanitarian, million, aid, assistance, fundi...
# 222    [humanitarian, eu, million, european, aid, mll...
# 84     [workers, aid, humanitarian, killed, worker, a...
# 201    [humanitarian, returns, displaced, violence, c...
# 220    [red, cross, ifrc, crescent, volunteers, icrc,...
# 161    [oxfam, oxfams, aid, humanitarian, clean, wate...
# 198    [maban, aid, workers, bunj, mabaan, mabanese, ...
# 12     [unmiss, un, civilians, mission, peacekeepers,...
# 209    [ngos, aid, workers, bill, permit, work, ngo, ...
# 88     [darfur, unamid, dabanga, radio, camp, west, d...
#
#                                      Representative_Docs
# Topic
# 31     [International donors today pledged more than ...
# 222    [Brussels — EU Commissioner for Humanitarian A...
# 84     [Juba, South Sudan — Six staff members of a na...
# 201    [Juba — Aid workers warn that while psychosoci...
# 220    [The South Sudan Red Cross (SSRC) has today be...
# 161    [A new wave of violence in Darfur has forced m...
# 198    [Addis Ababa — Early this week, a militia grou...
# 12     [Juba — The United Nations Mission in South Su...
# 209    [Foreign aid groups are facing pressure in sev...
# 88     [The failure of the UN/African Union ("hybrid"...

# %%
# Get the top 10 topics related to the keywords 'conflict', 'fighting', and 'murder'
relevant_topics = get_relevant_topics(bertopic_model = bertopic, keywords=['conflict', 'fighting', 'murder'], top_n=10)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)
    
df["conflict"] = [t in topic_ids for t in bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 217 0.3455478
# 216 0.3360504
# 128 0.33460623
# 205 0.33157223
# 169 0.32353568
# 158 0.31698716
# 200 0.31670505
# 87 0.31475306
# 137 0.31329644
# 0 0.30282426
#        Count                                     Name  \
# Topic
# 217       11         217_dinka_is_african_equatorians
# 216       11     216_society_civil_civilsociety_games
# 128       25  128_penalty_death_executions_moratorium
# 205       12      205_peace_splma_political_dividends
# 169       17   169_troika_rarcss_parties_transitional
# 158       19    158_journalists_cpj_journalist_killed
# 200       13          200_mbugua_gredo_kimani_ngarama
# 87        37            87_district_moyo_lamwo_border
# 137       23             137_toner_question_lyman_you
# 0        931            0_igad_machar_peace_agreement
#
#                                           Representation  \
# Topic
# 217    [dinka, is, african, equatorians, nuer, for, t...
# 216    [society, civil, civilsociety, games, process,...
# 128    [penalty, death, executions, moratorium, legal...
# 205    [peace, splma, political, dividends, is, these...
# 169    [troika, rarcss, parties, transitional, peace,...
# 158    [journalists, cpj, journalist, killed, alzinta...
# 200    [mbugua, gredo, kimani, ngarama, she, her, ken...
# 87     [district, moyo, lamwo, border, were, police, ...
# 137    [toner, question, lyman, you, kordofan, we, nu...
# 0      [igad, machar, peace, agreement, talks, partie...
#
#                                      Representative_Docs
# Topic
# 217    [The Big Bang of South Sudan is on since Sunda...
# 216    [The inclusion of civil society in efforts to ...
# 128    [Juba — South Sudan should join the great majo...
# 205    [It seems the deadlock in the negotiation over...
# 169    [The following statement was issued jointly by...
# 158    [Somalia continues to stand out as the African...
# 200    [Monica Kimani's father Paul Ngarama has dismi...
# 87     [A suspected South Sudan rebel group operating...
# 137    [Washington, DC — Excerpts from the United Sta...
# 0      [From the very outset, I want to lay a renunci...

# %%
new_keywords_added = ["summary", "hunger", "refugees", "humanitarian"]

# %%
keywords_list_extensive = ['Governance',
                           'Diplomacy',
                           'Conflict',
                           'Crisis',
                           'Security',
                           'Society',
                           'Health',
                           'Development',
                           'Education',
                           'Survival',
                           'International',
                           'Opposition',
                           'Welfare',
                           'Media',
                           'Leadership']

# %%
# Define the list of keywords
keywords_list_extensive = ['Governance', 'Diplomacy', 'Conflict', 'Crisis', 'Security', 'Society', 'Health', 'Development', 'Education', 'Survival', 'International', 'Opposition', 'Welfare', 'Media', 'Leadership']

# Initialize an empty dictionary to store the results for each keyword
keyword_results = {}

for keyword in keywords_list_extensive:
    # Get relevant topics for the current keyword
    relevant_topics = get_relevant_topics(bertopic_model=bertopic, keywords=[keyword], top_n=10)
    
    # Extract topic IDs
    topic_ids = [el[0] for el in relevant_topics]
    
    # Add a boolean column to df for the current keyword
    df[keyword] = [t in topic_ids for t in bertopic.topics_]
    
    # Store relevant topic information in the dictionary
    keyword_results[keyword] = bertopic.get_topic_info().set_index('Topic').loc[topic_ids]

# Print the results for each keyword
for keyword, result_df in keyword_results.items():
    print(f"Keyword: {keyword}")
    print(result_df)
    print("\n")
# Out:
# Keyword: Governance
#        Count                                               Name  \
# Topic
# 54        51                54_federal_system_federalism_kokora
# 216       11               216_society_civil_civilsociety_games
# 169       17             169_troika_rarcss_parties_transitional
# 195       13               195_child_children_rights_convention
# 90        34  90_conference_development_international_engage...
# 140       22  140_constitution_commission_society_constituti...
# 192       14         192_elections_constitution_bill_commission
# 40        67                         40_splm_party_political_it
# 15       138                     15_au_commission_african_union
# 114       29             114_rights_human_violations_commission
#
#                                           Representation  \
# Topic
# 54     [federal, system, federalism, kokora, powers, ...
# 216    [society, civil, civilsociety, games, process,...
# 169    [troika, rarcss, parties, transitional, peace,...
# 195    [child, children, rights, convention, crc, chi...
# 90     [conference, development, international, engag...
# 140    [constitution, commission, society, constituti...
# 192    [elections, constitution, bill, commission, pa...
# 40     [splm, party, political, it, is, the, not, thi...
# 15     [au, commission, african, union, council, chai...
# 114    [rights, human, violations, commission, crimes...
#
#                                      Representative_Docs
# Topic
# 54     [A federal system of government appropriate fo...
# 216    [The inclusion of civil society in efforts to ...
# 169    [The following statement was issued jointly by...
# 195    [Juba — UNICEF and religious leaders drawn fro...
# 90     [U.S. DEPARTMENT OF STATE Office of the Spokes...
# 140    [SOUTH SUDAN HUMAN RIGHTS SOCIETY FOR ADVOCACY...
# 192    [Juba — An alliance of South Sudanese oppositi...
# 40     [The Sudan People's Liberation Movement (SPLM)...
# 15     [Members of the African Union Peace and Securi...
# 114    [The undersigned non-governmental organization...
#
#
# Keyword: Diplomacy
#        Count                                               Name  \
# Topic
# 49        58              49_relations_ghandour_foreign_between
# 179       16                   179_ambassador_booth_lyman_think
# 89        34                         89_psaki_question_egypt_ms
# 225       10                     225_isaias_asmara_afwerki_nial
# 136       23                  136_abyei_issues_referendum_final
# 213       11                         213_booth_us_special_envoy
# 175       16                   175_trade_countries_minister_two
# 215       11                       215_blair_agi_somali_british
# 90        34  90_conference_development_international_engage...
# 133       24               133_eritrean_yohannes_asmara_eritrea
#
#                                           Representation  \
# Topic
# 49     [relations, ghandour, foreign, between, sudan,...
# 179    [ambassador, booth, lyman, think, question, yo...
# 89     [psaki, question, egypt, ms, you, egyptian, de...
# 225    [isaias, asmara, afwerki, nial, president, eri...
# 136    [abyei, issues, referendum, final, panel, coun...
# 213    [booth, us, special, envoy, corker, crisis, su...
# 175    [trade, countries, minister, two, economic, co...
# 215    [blair, agi, somali, british, minister, challe...
# 90     [conference, development, international, engag...
# 133    [eritrean, yohannes, asmara, eritrea, ambassad...
#
#                                      Representative_Docs
# Topic
# 49     [Khartoum — Sudan and South Sudan have agreed ...
# 179    [FOREIGN PRESS CENTER WITH AMBASSADOR DONALD B...
# 89     [On — Excerpt from the United States Departmen...
# 225    [Asmara — President Isaias Afwerki returned ho...
# 136    [Addis Ababa — The African Union Roadmap and t...
# 213    [Washington, DC — Dear Secretary John Kerry, A...
# 175    [Khartoum — The Minister for Trade Hatim al Si...
# 215    [Juba — Former British Prime Minister Tony Bla...
# 90     [U.S. DEPARTMENT OF STATE Office of the Spokes...
# 133    [Asmara — Heads of the Eritrean community in S...
#
#
# Keyword: Conflict
#        Count                                    Name  \
# Topic
# 217       11        217_dinka_is_african_equatorians
# 216       11    216_society_civil_civilsociety_games
# 205       12     205_peace_splma_political_dividends
# 169       17  169_troika_rarcss_parties_transitional
# 137       23            137_toner_question_lyman_you
# 0        931           0_igad_machar_peace_agreement
# 5        241                  5_our_you_is_political
# 146       21        146_khartoum_bashir_sudan_rebels
# 1        331               1_murle_jonglei_lou_pibor
# 126       25            126_splmn_arman_talks_darfur
#
#                                           Representation  \
# Topic
# 217    [dinka, is, african, equatorians, nuer, for, t...
# 216    [society, civil, civilsociety, games, process,...
# 205    [peace, splma, political, dividends, is, these...
# 169    [troika, rarcss, parties, transitional, peace,...
# 137    [toner, question, lyman, you, kordofan, we, nu...
# 0      [igad, machar, peace, agreement, talks, partie...
# 5      [our, you, is, political, it, and, not, we, of...
# 146    [khartoum, bashir, sudan, rebels, sudans, kiir...
# 1      [murle, jonglei, lou, pibor, bor, nuer, county...
# 126    [splmn, arman, talks, darfur, rebel, blue, kor...
#
#                                      Representative_Docs
# Topic
# 217    [The Big Bang of South Sudan is on since Sunda...
# 216    [The inclusion of civil society in efforts to ...
# 205    [It seems the deadlock in the negotiation over...
# 169    [The following statement was issued jointly by...
# 137    [Washington, DC — Excerpts from the United Sta...
# 0      [From the very outset, I want to lay a renunci...
# 5      [The son of my brother, Kuir E Garang, Since y...
# 146    [Juba — The President of the Republic of South...
# 1      [Juba — South Sudan's Vice President, Riek Mac...
# 126    [Khartoum — The African Union High-Level Imple...
#
#
# Keyword: Crisis
#        Count                                         Name  \
# Topic
# 172       16                  172_genocide_rwanda_jay_our
# 201       13  201_humanitarian_returns_displaced_violence
# 88        37               88_darfur_unamid_dabanga_radio
# 205       12          205_peace_splma_political_dividends
# 7        198                    7_food_fao_million_famine
# 169       17       169_troika_rarcss_parties_transitional
# 0        931                0_igad_machar_peace_agreement
# 91        34                     91_coup_nuer_nuers_dinka
# 26        95             26_msf_medical_patients_hospital
# 31        89       31_humanitarian_million_aid_assistance
#
#                                           Representation  \
# Topic
# 172    [genocide, rwanda, jay, our, that, or, this, i...
# 201    [humanitarian, returns, displaced, violence, c...
# 88     [darfur, unamid, dabanga, radio, camp, west, d...
# 205    [peace, splma, political, dividends, is, these...
# 7      [food, fao, million, famine, hunger, wfp, inse...
# 169    [troika, rarcss, parties, transitional, peace,...
# 0      [igad, machar, peace, agreement, talks, partie...
# 91     [coup, nuer, nuers, dinka, machar, kiir, attem...
# 26     [msf, medical, patients, hospital, leer, staff...
# 31     [humanitarian, million, aid, assistance, fundi...
#
#                                      Representative_Docs
# Topic
# 172    [Adama Dieng, the UN Special Advisor on the Pr...
# 201    [Juba — Aid workers warn that while psychosoci...
# 88     [The failure of the UN/African Union ("hybrid"...
# 205    [It seems the deadlock in the negotiation over...
# 7      [Juba — Nearly 7 million people expected to be...
# 169    [The following statement was issued jointly by...
# 0      [From the very outset, I want to lay a renunci...
# 91     [If there is someone who still hesitated that ...
# 26     [Juba/Amsterdam — Médecins Sans Frontières (MS...
# 31     [International donors today pledged more than ...
#
#
# Keyword: Security
#        Count                                   Name  \
# Topic
# 116       28     116_nss_detention_detainees_rights
# 199       13         199_police_criminals_crime_cid
# 163       18    163_police_magaya_officers_interior
# 76        39           76_abyei_unisfa_council_area
# 4        267  4_media_journalists_radio_information
# 16       134           16_unmiss_mission_un_council
# 28        91        28_rights_human_watch_civilians
# 12       149         12_unmiss_un_civilians_mission
# 218       10     218_kordofan_un_human_humanitarian
# 62        46        62_arms_embargo_weapons_amnesty
#
#                                           Representation  \
# Topic
# 116    [nss, detention, detainees, rights, bill, huma...
# 199    [police, criminals, crime, cid, juba, uniform,...
# 163    [police, magaya, officers, interior, alison, s...
# 76     [abyei, unisfa, council, area, security, manda...
# 4      [media, journalists, radio, information, journ...
# 16     [unmiss, mission, un, council, mandate, protec...
# 28     [rights, human, watch, civilians, nuer, soldie...
# 12     [unmiss, un, civilians, mission, peacekeepers,...
# 218    [kordofan, un, human, humanitarian, rights, at...
# 62     [arms, embargo, weapons, amnesty, council, san...
#
#                                      Representative_Docs
# Topic
# 116    [South Sudan's National Assembly should urgent...
# 199    [Juba — South Sudan on Friday vehemently downp...
# 163    [Juba — South Sudan's new minister of interior...
# 76     [In a new resolution, the Security Council tod...
# 4      [Juba — Following a series of attacks, intimid...
# 16     [Responding to the rapidly deteriorating secur...
# 28     [Nairobi — Both pro and antigovernment armed f...
# 12     [Juba — The United Nations Mission in South Su...
# 218    [United Nations — Witnesses reported that atta...
# 62     [The South Sudan arms embargo ends on May 31 b...
#
#
# Keyword: Society
#        Count                                  Name  \
# Topic
# 107       30    107_youth_youths_conference_sports
# 5        241                5_our_you_is_political
# 216       11  216_society_civil_civilsociety_games
# 54        51   54_federal_system_federalism_kokora
# 104       31        104_marriage_girls_child_dowry
# 34        82            34_women_womens_gender_she
# 157       20          157_garbage_city_mayor_clean
# 38        72         38_sexual_women_rape_violence
# 40        67            40_splm_party_political_it
# 116       28    116_nss_detention_detainees_rights
#
#                                           Representation  \
# Topic
# 107    [youth, youths, conference, sports, young, dig...
# 5      [our, you, is, political, it, and, not, we, of...
# 216    [society, civil, civilsociety, games, process,...
# 54     [federal, system, federalism, kokora, powers, ...
# 104    [marriage, girls, child, dowry, her, bride, ma...
# 34     [women, womens, gender, she, you, girls, and, ...
# 157    [garbage, city, mayor, clean, cleaning, juba, ...
# 38     [sexual, women, rape, violence, girls, raped, ...
# 40     [splm, party, political, it, is, the, not, thi...
# 116    [nss, detention, detainees, rights, bill, huma...
#
#                                      Representative_Docs
# Topic
# 107    [Bor — The youth and sports minister in South ...
# 5      [The son of my brother, Kuir E Garang, Since y...
# 216    [The inclusion of civil society in efforts to ...
# 54     [A federal system of government appropriate fo...
# 104    [Nairobi — Akech B. loved to study and dreamed...
# 34     [U.S. Secretary of State Hillary Rodham Clinto...
# 157    [Young South Sudanese have been meeting every ...
# 38     [Widespread sexual violence against women and ...
# 40     [The Sudan People's Liberation Movement (SPLM)...
# 116    [South Sudan's National Assembly should urgent...
#
#
# Keyword: Health
#        Count                                        Name  \
# Topic
# 85        38         85_health_hospital_doctors_ministry
# 121       27  121_malnutrition_children_unicef_nutrition
# 45        62              45_malaria_health_disease_worm
# 106       30         106_hiv_hivaids_aids_antiretroviral
# 149       20    149_covid19_health_response_surveillance
# 92        34            92_health_maternal_women_fistula
# 35        77          35_cholera_outbreak_health_disease
# 26        95            26_msf_medical_patients_hospital
# 52        53        52_covid19_health_coronavirus_tested
# 63        46                 63_wfp_food_assistance_wfps
#
#                                           Representation  \
# Topic
# 85     [health, hospital, doctors, ministry, medical,...
# 121    [malnutrition, children, unicef, nutrition, ac...
# 45     [malaria, health, disease, worm, guinea, cases...
# 106    [hiv, hivaids, aids, antiretroviral, treatment...
# 149    [covid19, health, response, surveillance, idsr...
# 92     [health, maternal, women, fistula, she, her, u...
# 35     [cholera, outbreak, health, disease, cases, wa...
# 26     [msf, medical, patients, hospital, leer, staff...
# 52     [covid19, health, coronavirus, tested, virus, ...
# 63     [wfp, food, assistance, wfps, million, contrib...
#
#                                      Representative_Docs
# Topic
# 85     [Juba — The minister for Health, Hon Dr Michae...
# 121    [Thousands of children under the age of five a...
# 45     [Large spikes in malaria across South Sudan ar...
# 106    [Juba — The President of the Republic of South...
# 149    [The Ministry of Health in collaboration with ...
# 92     [Juba — Martha Borete Angela's gaze sinks to t...
# 35     [Juba — The caseload of cholera is rapidly inc...
# 26     [Juba/Amsterdam — Médecins Sans Frontières (MS...
# 52     [Four senior officials working in South Sudan'...
# 63     [Juba — Any views expressed in this article ar...
#
#
# Keyword: Development
#        Count                                               Name  \
# Topic
# 43        66              43_labour_training_service_vocational
# 107       30                 107_youth_youths_conference_sports
# 77        39                      77_bank_imf_development_banks
# 51        54                           51_ict_internet_mtn_code
# 169       17             169_troika_rarcss_parties_transitional
# 53        52                 53_road_roads_construction_project
# 177       16         177_mabuza_deputy_consultative_revitalised
# 90        34  90_conference_development_international_engage...
# 111       29          111_investment_investors_business_private
# 2        287             2_education_students_university_school
#
#                                           Representation  \
# Topic
# 43     [labour, training, service, vocational, public...
# 107    [youth, youths, conference, sports, young, dig...
# 77     [bank, imf, development, banks, world, afdb, f...
# 51     [ict, internet, mtn, code, itu, network, cable...
# 169    [troika, rarcss, parties, transitional, peace,...
# 53     [road, roads, construction, project, bridges, ...
# 177    [mabuza, deputy, consultative, revitalised, pr...
# 90     [conference, development, international, engag...
# 111    [investment, investors, business, private, opp...
# 2      [education, students, university, school, univ...
#
#                                      Representative_Docs
# Topic
# 43     [Juba — The Juba Multi-Service Training Centre...
# 107    [Bor — The youth and sports minister in South ...
# 77     [Washington — The World Bank Board of Director...
# 51     [Juba — The Minister of Telecommunication and ...
# 169    [The following statement was issued jointly by...
# 53     [Nairobi — Several road construction companies...
# 177    [Deputy President David Mabuza has arrived in ...
# 90     [U.S. DEPARTMENT OF STATE Office of the Spokes...
# 111    [Juba — South Sudan said Friday it will host a...
# 2      [In the first part of this article, we had sai...
#
#
# Keyword: Education
#        Count                                               Name  \
# Topic
# 2        287             2_education_students_university_school
# 107       30                 107_youth_youths_conference_sports
# 43        66              43_labour_training_service_vocational
# 104       31                     104_marriage_girls_child_dowry
# 60        47                  60_children_child_unicef_soldiers
# 132       24                     132_children_boys_unicef_child
# 121       27         121_malnutrition_children_unicef_nutrition
# 59        49                         59_music_film_jal_audience
# 90        34  90_conference_development_international_engage...
# 195       13               195_child_children_rights_convention
#
#                                           Representation  \
# Topic
# 2      [education, students, university, school, univ...
# 107    [youth, youths, conference, sports, young, dig...
# 43     [labour, training, service, vocational, public...
# 104    [marriage, girls, child, dowry, her, bride, ma...
# 60     [children, child, unicef, soldiers, release, r...
# 132    [children, boys, unicef, child, armed, recruit...
# 121    [malnutrition, children, unicef, nutrition, ac...
# 59     [music, film, jal, audience, theatre, festival...
# 90     [conference, development, international, engag...
# 195    [child, children, rights, convention, crc, chi...
#
#                                      Representative_Docs
# Topic
# 2      [In the first part of this article, we had sai...
# 107    [Bor — The youth and sports minister in South ...
# 43     [Juba — The Juba Multi-Service Training Centre...
# 104    [Nairobi — Akech B. loved to study and dreamed...
# 60     [Nairobi — The government of South Sudan signe...
# 132    [Almost two years since the eruption of the co...
# 121    [Thousands of children under the age of five a...
# 59     [South Sudan's famous son Panchol Deng Ajang L...
# 90     [U.S. DEPARTMENT OF STATE Office of the Spokes...
# 195    [Juba — UNICEF and religious leaders drawn fro...
#
#
# Keyword: Survival
#        Count                                         Name  \
# Topic
# 26        95             26_msf_medical_patients_hospital
# 161       19            161_oxfam_oxfams_aid_humanitarian
# 220       10                  220_red_cross_ifrc_crescent
# 130       25                130_fire_brigade_hotel_market
# 95        33                  95_kakuma_camp_her_refugees
# 201       13  201_humanitarian_returns_displaced_violence
# 171       17              171_food_unhcr_refugees_refugee
# 172       16                  172_genocide_rwanda_jay_our
# 156       20                  156_icrc_red_cross_surgical
# 7        198                    7_food_fao_million_famine
#
#                                           Representation  \
# Topic
# 26     [msf, medical, patients, hospital, leer, staff...
# 161    [oxfam, oxfams, aid, humanitarian, clean, wate...
# 220    [red, cross, ifrc, crescent, volunteers, icrc,...
# 130    [fire, brigade, hotel, market, accident, shops...
# 95     [kakuma, camp, her, refugees, refugee, she, my...
# 201    [humanitarian, returns, displaced, violence, c...
# 171    [food, unhcr, refugees, refugee, children, sho...
# 172    [genocide, rwanda, jay, our, that, or, this, i...
# 156    [icrc, red, cross, surgical, maurer, wounded, ...
# 7      [food, fao, million, famine, hunger, wfp, inse...
#
#                                      Representative_Docs
# Topic
# 26     [Juba/Amsterdam — Médecins Sans Frontières (MS...
# 161    [A new wave of violence in Darfur has forced m...
# 220    [The South Sudan Red Cross (SSRC) has today be...
# 130    [Juba — The Sudan People Liberation Movement (...
# 95     [Kakuma — Physical space and timely protection...
# 201    [Juba — Aid workers warn that while psychosoci...
# 171    [The United Nations refugee agency today expre...
# 172    [Adama Dieng, the UN Special Advisor on the Pr...
# 156    [Geneva — Since the first armed clashes broke ...
# 7      [Juba — Nearly 7 million people expected to be...
#
#
# Keyword: International
#        Count                                               Name  \
# Topic
# 51        54                           51_ict_internet_mtn_code
# 178       16                    178_icglr_luanda_angola_burundi
# 18       122                              18_eac_east_join_bloc
# 111       29          111_investment_investors_business_private
# 90        34  90_conference_development_international_engage...
# 77        39                      77_bank_imf_development_banks
# 133       24               133_eritrean_yohannes_asmara_eritrea
# 82        38                      82_football_sports_team_sport
# 145       21       145_passports_passport_documents_nationality
# 203       12                      203_angolan_luanda_angola_dos
#
#                                           Representation  \
# Topic
# 51     [ict, internet, mtn, code, itu, network, cable...
# 178    [icglr, luanda, angola, burundi, summit, repub...
# 18     [eac, east, join, bloc, community, arusha, bur...
# 111    [investment, investors, business, private, opp...
# 90     [conference, development, international, engag...
# 77     [bank, imf, development, banks, world, afdb, f...
# 133    [eritrean, yohannes, asmara, eritrea, ambassad...
# 82     [football, sports, team, sport, match, players...
# 145    [passports, passport, documents, nationality, ...
# 203    [angolan, luanda, angola, dos, santos, eduardo...
#
#                                      Representative_Docs
# Topic
# 51     [Juba — The Minister of Telecommunication and ...
# 178    [Luanda — The President of South Sudan, Salva ...
# 18     [Amb. Dr. Richard Sezibera the Secretary Gener...
# 111    [Juba — South Sudan said Friday it will host a...
# 90     [U.S. DEPARTMENT OF STATE Office of the Spokes...
# 77     [Washington — The World Bank Board of Director...
# 133    [Asmara — Heads of the Eritrean community in S...
# 82     [Instead of celebrating the senior women's nat...
# 145    [Juba — The Director General for Nationality, ...
# 203    [Luanda — Emmanuel Lewilla, special envoy of t...
#
#
# Keyword: Opposition
#        Count                                    Name  \
# Topic
# 73        40                73_almahdi_nup_party_ncp
# 40        67              40_splm_party_political_it
# 50        55               50_lra_kony_central_congo
# 217       11        217_dinka_is_african_equatorians
# 98        32                98_splmdc_akol_lam_party
# 28        91         28_rights_human_watch_civilians
# 191       14               191_dinka_hag_tearz_naath
# 5        241                  5_our_you_is_political
# 169       17  169_troika_rarcss_parties_transitional
# 218       10      218_kordofan_un_human_humanitarian
#
#                                           Representation  \
# Topic
# 73     [almahdi, nup, party, ncp, dialogue, congress,...
# 40     [splm, party, political, it, is, the, not, thi...
# 50     [lra, kony, central, congo, lords, drc, milita...
# 217    [dinka, is, african, equatorians, nuer, for, t...
# 98     [splmdc, akol, lam, party, splm, dr, oppositio...
# 28     [rights, human, watch, civilians, nuer, soldie...
# 191    [dinka, hag, tearz, naath, aturjong, el, you, ...
# 5      [our, you, is, political, it, and, not, we, of...
# 169    [troika, rarcss, parties, transitional, peace,...
# 218    [kordofan, un, human, humanitarian, rights, at...
#
#                                      Representative_Docs
# Topic
# 73     [Khartoum — The national dialogue committee kn...
# 40     [The Sudan People's Liberation Movement (SPLM)...
# 50     [On 5 March Invisible Children Inc. launched K...
# 217    [The Big Bang of South Sudan is on since Sunda...
# 98     [We all know that Dr Lam Akol Graduated with a...
# 28     [Nairobi — Both pro and antigovernment armed f...
# 191    [Juba — A South Sudanese army general who rece...
# 5      [The son of my brother, Kuir E Garang, Since y...
# 169    [The following statement was issued jointly by...
# 218    [United Nations — Witnesses reported that atta...
#
#
# Keyword: Welfare
#        Count                                        Name  \
# Topic
# 31        89      31_humanitarian_million_aid_assistance
# 121       27  121_malnutrition_children_unicef_nutrition
# 63        46                 63_wfp_food_assistance_wfps
# 209       12                   209_ngos_aid_workers_bill
# 167       17     167_pension_pensioners_pensions_service
# 222       10        222_humanitarian_eu_million_european
# 161       19           161_oxfam_oxfams_aid_humanitarian
# 7        198                   7_food_fao_million_famine
# 171       17             171_food_unhcr_refugees_refugee
# 41        67             41_budget_ssp_finance_austerity
#
#                                           Representation  \
# Topic
# 31     [humanitarian, million, aid, assistance, fundi...
# 121    [malnutrition, children, unicef, nutrition, ac...
# 63     [wfp, food, assistance, wfps, million, contrib...
# 209    [ngos, aid, workers, bill, permit, work, ngo, ...
# 167    [pension, pensioners, pensions, service, emplo...
# 222    [humanitarian, eu, million, european, aid, mll...
# 161    [oxfam, oxfams, aid, humanitarian, clean, wate...
# 7      [food, fao, million, famine, hunger, wfp, inse...
# 171    [food, unhcr, refugees, refugee, children, sho...
# 41     [budget, ssp, finance, austerity, tax, spendin...
#
#                                      Representative_Docs
# Topic
# 31     [International donors today pledged more than ...
# 121    [Thousands of children under the age of five a...
# 63     [Juba — Any views expressed in this article ar...
# 209    [Foreign aid groups are facing pressure in sev...
# 167    [The issue of the pensioners still remain dubi...
# 222    [Brussels — EU Commissioner for Humanitarian A...
# 161    [A new wave of violence in Darfur has forced m...
# 7      [Juba — Nearly 7 million people expected to be...
# 171    [The United Nations refugee agency today expre...
# 41     [Juba — South Sudan finance minister, Agrey Ti...
#
#
# Keyword: Media
#        Count                                   Name  \
# Topic
# 4        267  4_media_journalists_radio_information
# 158       19  158_journalists_cpj_journalist_killed
# 59        49             59_music_film_jal_audience
# 172       16            172_genocide_rwanda_jay_our
# 51        54               51_ict_internet_mtn_code
# 38        72          38_sexual_women_rape_violence
# 130       25          130_fire_brigade_hotel_market
# 9        170    9_corruption_money_public_officials
# 107       30     107_youth_youths_conference_sports
# 82        38          82_football_sports_team_sport
#
#                                           Representation  \
# Topic
# 4      [media, journalists, radio, information, journ...
# 158    [journalists, cpj, journalist, killed, alzinta...
# 59     [music, film, jal, audience, theatre, festival...
# 172    [genocide, rwanda, jay, our, that, or, this, i...
# 51     [ict, internet, mtn, code, itu, network, cable...
# 38     [sexual, women, rape, violence, girls, raped, ...
# 130    [fire, brigade, hotel, market, accident, shops...
# 9      [corruption, money, public, officials, sentry,...
# 107    [youth, youths, conference, sports, young, dig...
# 82     [football, sports, team, sport, match, players...
#
#                                      Representative_Docs
# Topic
# 4      [Juba — Following a series of attacks, intimid...
# 158    [Somalia continues to stand out as the African...
# 59     [South Sudan's famous son Panchol Deng Ajang L...
# 172    [Adama Dieng, the UN Special Advisor on the Pr...
# 51     [Juba — The Minister of Telecommunication and ...
# 38     [Widespread sexual violence against women and ...
# 130    [Juba — The Sudan People Liberation Movement (...
# 9      [To the consternation of the 'Oyee party' lead...
# 107    [Bor — The youth and sports minister in South ...
# 82     [Instead of celebrating the senior women's nat...
#
#
# Keyword: Leadership
#        Count                                        Name  \
# Topic
# 107       30          107_youth_youths_conference_sports
# 151       20                      151_hitler_kiir_his_he
# 43        66       43_labour_training_service_vocational
# 79        39                79_ramaphosa_deputy_anc_splm
# 44        63        44_police_officers_rwanda_contingent
# 196       13                   196_army_spla_marking_mai
# 36        73     36_governor_speaker_parliament_assembly
# 153       20                    153_twic_county_bor_east
# 177       16  177_mabuza_deputy_consultative_revitalised
# 206       12                206_party_splm_partys_splmdc
#
#                                           Representation  \
# Topic
# 107    [youth, youths, conference, sports, young, dig...
# 151    [hitler, kiir, his, he, him, splm, nuer, like,...
# 43     [labour, training, service, vocational, public...
# 79     [ramaphosa, deputy, anc, splm, reunification, ...
# 44     [police, officers, rwanda, contingent, rwandan...
# 196    [army, spla, marking, mai, weapons, general, t...
# 36     [governor, speaker, parliament, assembly, stat...
# 153    [twic, county, bor, east, akol, community, mem...
# 177    [mabuza, deputy, consultative, revitalised, pr...
# 206    [party, splm, partys, splmdc, ruling, liberati...
#
#                                      Representative_Docs
# Topic
# 107    [Bor — The youth and sports minister in South ...
# 151    ["There is time for everything, time for sadne...
# 43     [Juba — The Juba Multi-Service Training Centre...
# 79     [Deputy President Cyril Ramaphosa in his capac...
# 44     [Bruce Munyambo, a commissioner at Rwanda Nati...
# 196    [Juba — The South Sudan Army (SPLA) chief of s...
# 36     [Juba — A group of MPs in Northern Bahr el Gha...
# 153    [Dear Community, Our members of Bor County are...
# 177    [Deputy President David Mabuza has arrived in ...
# 206    [Juba — The Sudan Peoples' Liberation Movement...

# %%
final_keywords= new_keywords_added + keywords_list_extensive

# %%
df

# %%
original_df = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"])


# Combine article summaries with the newly created features
df = original_df.merge(
    df[final_keywords],
    how="left",
    left_on="summary",
    right_on="summary",
)

df.to_csv("data/articles_topics.csv", index=False) # Save DataFrame to articles_topics.csv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/egor/Desktop/Study Materials/DC3-Group-13/topic_modelling.ipynb Cell 19 line 6
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> original_df = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"])
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> # Combine article summaries with the newly created features
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> df = original_df.merge(
# ----> <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a>     df[final_keywords],
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a>     how="left",
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a>     left_on="summary",
#       <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a>     right_on="summary",
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> )
#      <a href='vscode-notebook-cell:/home/egor/Desktop/Study%20Materials/DC3-Group-13/topic_modelling.ipynb#X32sZmlsZQ%3D%3D?line=11'>12</a> df.to_csv("data/articles_topics.csv", index=False) # Save DataFrame to articles_topics.csv
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['summary'] not in index"

# %%
# original_df = pd.read_csv("data/all_africa_southsudan.csv", parse_dates=["date"])

# Combine article summaries with the newly created features
# df = original_df.merge(
#     df[final_keywords],
#     how="left",
#     left_on="paragraphs",
#     right_on="paragraphs",
# )

# df.to_csv("data/articles_topics.csv", index=False) # Save DataFrame to articles_topics.csv

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18226 entries, 0 to 18225
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       18226 non-null  object
#  1   date        18226 non-null  datetime64[ns]
#  2   paragraphs  18226 non-null  object
#  3   publisher   18226 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 569.7+ KB

# %%
print(len(df))
print(len(df[(df["hunger"]==False) & (df["refugees"] == False) & (df["humanitarian"] == False) & (df["conflict"] == False)]))
# Out:
# 18226
# 15752

# %% [markdown]
# There are a lot of articles that do not get sorted into either of the categories. So, feel free to change or expand this approach!
